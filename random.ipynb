# %%
import os
import soundfile

# %%
for dirpath, dirnames, filenames in os.walk('Audio_Song_Actors_01-24'):
    print(dirpath, dirnames, filenames)
# Out:
# Audio_Song_Actors_01-24 ['Actor_22', 'Actor_10', 'Actor_19', 'Actor_01', 'Actor_04', 'Actor_18', 'Actor_06', 'Actor_08', 'Actor_20', 'Actor_07', 'Actor_11', 'Actor_16', 'Actor_02', 'Actor_12', 'Actor_03', 'Actor_13', 'Actor_14', 'Actor_24', 'Actor_17', 'Actor_23', 'Actor_05', 'Actor_21', 'Actor_15', 'Actor_09'] []
# ...
